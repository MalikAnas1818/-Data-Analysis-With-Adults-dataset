# %% [markdown]
# # Data link: https://www.kaggle.com/datasets/wenruliu/adult-income-dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("Adult.csv")

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# # 1.Display Top 10 Rows of The Dataset

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %% [markdown]
# # 2. Check Last 10 Rows of The Dataset

# %%
df.tail()
# Out:
#        age     workclass  fnlwgt   education  educational-num  \
# 48837   27       Private  257302  Assoc-acdm               12
# 48838   40       Private  154374     HS-grad                9
# 48839   58       Private  151910     HS-grad                9
# 48840   22       Private  201490     HS-grad                9
# 48841   52  Self-emp-inc  287927     HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48837             0             0              38  United-States  <=50K
# ...

# %% [markdown]
# # 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
print('Number of columns:',df.shape[1])
print('Number of rows:',df.shape[0])
# Out:
# Number of columns: 15
# Number of rows: 48842

# %% [markdown]
# # 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# # 5. Fetch Random Sample From the Dataset (50%)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df.sample(frac=0.5)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 29662   33  Self-emp-not-inc  188957     Bachelors               13
# 9873    62           Private  216765     Bachelors               13
# 18665   19           Private  172893  Some-college               10
# 41884   28           Private  110164  Some-college               10
# 39963   42           Private  331651       Masters               14
# ...    ...               ...     ...           ...              ...
# 45226   17           Private  147069          10th                6
# 4493    32           Private   37646  Some-college               10
# 14462   24           Private  142566          10th                6
# 39281   50           Private  217577       HS-grad                9
# 37897   55           Private  129762       HS-grad                9
#
#            marital-status         occupation    relationship   race  gender  \
# ...

# %% [markdown]
# # 6.Check Null Values In The Dataset

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %% [markdown]
# # 7.Perform Data Cleaning [ Replace '?' with NaN ]

# %%
d=df.replace('?',np.nan)

# %%
d.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
d[d.isna()]
# Out:
#        age workclass  fnlwgt education  educational-num marital-status  \
# 0      NaN       NaN     NaN       NaN              NaN            NaN
# 1      NaN       NaN     NaN       NaN              NaN            NaN
# 2      NaN       NaN     NaN       NaN              NaN            NaN
# 3      NaN       NaN     NaN       NaN              NaN            NaN
# 4      NaN       NaN     NaN       NaN              NaN            NaN
# ...    ...       ...     ...       ...              ...            ...
# 48837  NaN       NaN     NaN       NaN              NaN            NaN
# 48838  NaN       NaN     NaN       NaN              NaN            NaN
# 48839  NaN       NaN     NaN       NaN              NaN            NaN
# 48840  NaN       NaN     NaN       NaN              NaN            NaN
# 48841  NaN       NaN     NaN       NaN              NaN            NaN
#
#       occupation relationship race gender  capital-gain  capital-loss  \
# ...

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
for i in df.columns:
    if len(df[df[i]=='?'])>0:
        print(f"? exist in colums {i}")
# Out:
# ? exist in colums workclass
# ? exist in colums occupation
# ? exist in colums native-country

# %%
df[df['workclass']=='?']
# Out:
#        age workclass  fnlwgt     education  educational-num  \
# 4       18         ?  103497  Some-college               10
# 6       29         ?  227026       HS-grad                9
# 13      58         ?  299831       HS-grad                9
# 22      72         ?  132015       7th-8th                4
# 35      65         ?  191846       HS-grad                9
# ...    ...       ...     ...           ...              ...
# 48811   35         ?  320084     Bachelors               13
# 48812   30         ?   33811     Bachelors               13
# 48820   71         ?  287372     Doctorate               16
# 48822   41         ?  202822       HS-grad                9
# 48823   72         ?  129912       HS-grad                9
#
#            marital-status occupation   relationship                race  \
# 4           Never-married          ?      Own-child               White
# 6           Never-married          ?      Unmarried               Black
# ...

# %%
d[d['workclass']==np.nan]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, educational-num, marital-status, occupation, relationship, race, gender, capital-gain, capital-loss, hours-per-week, native-country, income]
# Index: []

# %%
d[d.notna()]
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
d.shape
# Out:
# (48842, 15)

# %%
d[d.isnull().any(axis=1)]
# Out:
#        age workclass  fnlwgt     education  educational-num  \
# 4       18       NaN  103497  Some-college               10
# 6       29       NaN  227026       HS-grad                9
# 13      58       NaN  299831       HS-grad                9
# 19      40   Private   85019     Doctorate               16
# 22      72       NaN  132015       7th-8th                4
# ...    ...       ...     ...           ...              ...
# 48811   35       NaN  320084     Bachelors               13
# 48812   30       NaN   33811     Bachelors               13
# 48820   71       NaN  287372     Doctorate               16
# 48822   41       NaN  202822       HS-grad                9
# 48823   72       NaN  129912       HS-grad                9
#
#            marital-status      occupation   relationship                race  \
# 4           Never-married             NaN      Own-child               White
# 6           Never-married             NaN      Unmarried               Black
# ...

# %%
sns.heatmap(d.isnull())
plt.show()

# %% [markdown]
# # 8. Drop all The Missing Values

# %%
d.dropna()
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %%
d.dropna(how='any',inplace=True)

# %%
d.shape
# Out:
# (45222, 15)

# %% [markdown]
# # 10. Get Overall Statistics About The Dataframe

# %%
df.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   48842.000000     48842  4.884200e+04     48842     48842.000000
# unique           NaN         9           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33906           NaN     15784              NaN
# mean       38.643585       NaN  1.896641e+05       NaN        10.078089
# std        13.710510       NaN  1.056040e+05       NaN         2.570973
# min        17.000000       NaN  1.228500e+04       NaN         1.000000
# 25%        28.000000       NaN  1.175505e+05       NaN         9.000000
# 50%        37.000000       NaN  1.781445e+05       NaN        10.000000
# 75%        48.000000       NaN  2.376420e+05       NaN        12.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status      occupation relationship   race gender  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df['education'].unique()
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', 'Doctorate',
#        '5th-6th', 'Assoc-voc', '9th', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
df['educational-num'].unique()
# Out:
# array([ 7,  9, 12, 10,  6, 15,  4, 13, 14, 16,  3, 11,  5,  8,  2,  1],
#       dtype=int64)

# %%
plt.figure(figsize=(18,8))
sns.countplot(x='education',data=df)
plt.show()

# %%
df['education'].value_counts()
# Out:
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %%
df['education'].value_counts().sum()
# Out:
# 48842

# %%
plt.figure(figsize=(18,8))
sns.countplot(x='educational-num',data=df)
plt.show()

# %% [markdown]
# # 11. Drop The Columns education-num, capital-gain, and capital-loss

# %%
dp=df.drop(columns=['educational-num','capital-gain','capital-loss'])

# %%
dp
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 4       18             ?  103497  Some-college       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct    Own-child  Black    Male              40
# ...

# %% [markdown]
# # 12. What Is The Distribution of Age Column?

# %%
df[['age']].value_counts()
# Out:
# age
# 36     1348
# 35     1337
# 33     1335
# 23     1329
# 31     1325
#        ...
# 88        6
# 85        5
# 87        3
# 89        2
# 86        1
# Length: 74, dtype: int64

# %%
plt.figure(figsize=(18,8))
sns.countplot(x='age',data=df[df['age']<60])
plt.show()

# %%
df['age'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # 13. Find Total Number of Persons Having Age Between 17 To 48 (Inclusive) Using Between Method

# %%
sum((df['age']>=17) & (df['age']<=48))
# Out:
# 37321

# %%
sum(df['age'].between(17,48))
# Out:
# 37321

# %%
df1=(df['age']>=17) & (df['age']<=48)

# %%
plt.figure(figsize=(18,8))
sns.countplot(x='age',data=df[df1])
plt.show()

# %% [markdown]
# # 14. What is The Distribution of Workclass Column?

# %%
df2=df['workclass'].describe()

# %%
plt.figure(figsize=(12,8))
df['workclass'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # 15. How Many Persons Having Bachelors and Masters Degree?

# %%
df.head(5)
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df['education'].value_counts()
# Out:
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %%
df[df['education'].isin(['Bachelors','Masters'])]['education'].value_counts()
# Out:
# Bachelors    8025
# Masters      2657
# Name: education, dtype: int64

# %%
x=df[df['education'].isin(['Bachelors','Masters'])]

# %%
#plt.figure(figsize=(18,8))
sns.countplot(x='education',data=x)
plt.show()

# %% [markdown]
# # 16. Bivariate Analsis

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df[['income','age']]
# Out:
#       income  age
# 0      <=50K   25
# 1      <=50K   38
# 2       >50K   28
# 3       >50K   44
# 4      <=50K   18
# ...      ...  ...
# 48837  <=50K   27
# 48838   >50K   40
# 48839  <=50K   58
# 48840  <=50K   22
# 48841   >50K   52
#
# [48842 rows x 2 columns]

# %%
sns.boxplot(x='income',y='age',data=df)
plt.show()

# %% [markdown]
# # 17. Replace income values['<=50K' , '>50K'] With 0 and 1

# %%
df['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
df['income'].value_counts()
# Out:
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64

# %%
sns.countplot(x='income',data=df)
plt.show()

# %%
def salary_data(sal):
    if sal=='<=50K':
        return 0
    else:
        return 1

# %%
salary_data('<=50K')
# Out:
# 0

# %%
df['salary']=df['income'].apply(salary_data)

# %%
df.head(1)
# Out:
#    age workclass  fnlwgt education  educational-num marital-status  \
# 0   25   Private  226802      11th                7  Never-married
#
#           occupation relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black   Male             0             0
#
#    hours-per-week native-country income  salary
# 0              40  United-States  <=50K       0

# %%
df.shape[1]
# Out:
# 16

# %%
df1=df

# %%
df1.replace(to_replace=['<=50K', '>50K'],value=[0,1],inplace=True)

# %%
df1
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# # 18. Which Workclass Getting The Highest Salary?

# %%
df['workclass'].unique()
# Out:
# array(['Private', 'Local-gov', '?', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
df.groupby('workclass')['salary'].mean().sort_values(ascending=False)*100
# Out:
# workclass
# Self-emp-inc        55.339233
# Federal-gov         39.175978
# Local-gov           29.559949
# Self-emp-not-inc    27.887105
# State-gov           26.754165
# Private             21.786704
# Without-pay          9.523810
# ?                    9.467667
# Never-worked         0.000000
# Name: salary, dtype: float64

# %%
avg=df.groupby('workclass')['salary'].mean().sort_values(ascending=False)*100

# %%
avg
# Out:
# workclass
# Self-emp-inc        55.339233
# Federal-gov         39.175978
# Local-gov           29.559949
# Self-emp-not-inc    27.887105
# State-gov           26.754165
# Private             21.786704
# Without-pay          9.523810
# ?                    9.467667
# Never-worked         0.000000
# Name: salary, dtype: float64

# %%
plt.figure(figsize=(18,8))
sns.barplot(x=avg.index,y=avg.values)
plt.title('hightest Salary')
plt.xlabel('Wrok Class Name')
plt.ylabel('Salary Avarge')
plt.show()

# %% [markdown]
# # 19.How Has Better Chance To Get Salary greater than 50K Male or Female?

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income', 'salary'],
#       dtype='object')

# %%
df['gender'].value_counts()
# Out:
# Male      32650
# Female    16192
# Name: gender, dtype: int64

# %%
sns.countplot(x='gender',data=df)
plt.show()

# %%
hig=df.groupby('gender')['salary'].mean()*100

# %%
hig
# Out:
# gender
# Female    10.925148
# Male      30.376723
# Name: salary, dtype: float64

# %%
plt.figure(figsize=(5,4))
sns.barplot(x=hig.index,y=hig.values)
plt.title('Hightest Salary For MEN and Women')
plt.xlabel('Gender')
plt.ylabel('Avarger Salary')
plt.show()

# %% [markdown]
# # 20. Covert workclass Columns Datatype To Category Datatype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  int64
#  15  salary           48842 non-null  int64
# dtypes: int64(8), object(8)
# ...

# %%
df['workclass']=df['workclass'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  category
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  int64
#  15  salary           48842 non-null  int64
# dtypes: category(1), int64(8), object(7)
# ...

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
# ...

# %%
df['race'].unique()
# Out:
# array(['Black', 'White', 'Asian-Pac-Islander', 'Other',
#        'Amer-Indian-Eskimo'], dtype=object)

# %%
df['race'].value_counts()
# Out:
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: race, dtype: int64

# %%
sns.countplot(x='race',data=df)
plt.show()

# %%
df.groupby('race')['age'].mean()
# Out:
# race
# Amer-Indian-Eskimo    36.693617
# Asian-Pac-Islander    37.858460
# Black                 37.914408
# Other                 33.657635
# White                 38.824362
# Name: age, dtype: float64
